# %%
import json
from azure.cognitiveservices.personalizer import PersonalizerClient
from azure.cognitiveservices.personalizer.models import RankRequest
from msrest.authentication import CognitiveServicesCredentials
from exe_functions import build_path
import os

from azure.cognitiveservices.personalizer import PersonalizerClient
from azure.cognitiveservices.personalizer.models import RankableAction, RewardRequest, RankRequest
from msrest.authentication import CognitiveServicesCredentials

import datetime, json, os, time, uuid, random

with open(build_path(os.path.abspath(os.curdir) + ("\\.keys"), "azure-personalizer-key.txt"), 'r') as f:
     personalizer_key = f.read().rstrip()
client = PersonalizerClient(
    "https://bwh-pharmacoepi-roybal-dev-e2-ehr-cog.cognitiveservices.azure.com/", 
    CognitiveServicesCredentials(personalizer_key)
)

key = personalizer_key
endpoint = client

# Instantiate a Personalizer client
#client = PersonalizerClient(endpoint, CognitiveServicesCredentials(key))

# %%
actions_and_features = {
    'pasta': {
        'brand_info': {
            'company':'pasta_inc'
        }, 
        'attributes': {
            'qty':1, 'cuisine':'italian',
            'price':12
        },
        'dietary_attributes': {
            'vegan': False,
            'low_carb': False,
            'high_protein': False,
            'vegetarian': False,
            'low_fat': True,
            'low_sodium': True
        }
    },
    'bbq': {
        'brand_info' : {
            'company': 'ambisco'
        },
        'attributes': {
            'qty': 2,
            'category': 'bbq',
            'price': 20
        }, 
        'dietary_attributes': {
            'vegan': False,
            'low_carb': True,
            'high_protein': True,
            'vegetarian': False,
            'low_fat': False,
            'low_sodium': False
        }
    },
    'bao': {
        'brand_info': {
            'company': 'bao_and_co'
        },
        'attributes': {
            'qty': 4,
            'category': 'chinese',
            'price': 8
        }, 
        'dietary_attributes': {
            'vegan': False,
            'low_carb': True,
            'high_protein': True,
            'vegetarian': False,
            'low_fat': True,
            'low_sodium': False
        }
    },
    'hummus': {
        'brand_info' : { 
            'company': 'garbanzo_inc'
        },
        'attributes' : {
            'qty': 1,
            'category': 'breakfast',
            'price': 5
        }, 
        'dietary_attributes': {
            'vegan': True, 
            'low_carb': False,
            'high_protein': True,
            'vegetarian': True,
            'low_fat': False, 
            'low_sodium': False
        }
    },
    'veg_platter': {
        'brand_info': {
            'company': 'farm_fresh'
        }, 
        'attributes': {
            'qty': 1,
            'category': 'produce', 
            'price': 7
        },
        'dietary_attributes': {
            'vegan': True,
            'low_carb': True,
            'high_protein': False,
            'vegetarian': True,
            'low_fat': True,
            'low_sodium': True
        }
    }
}

def get_actions():
    res = []
    for action_id, feat in actions_and_features.items():
        action = RankableAction(id=action_id, features=[feat])
        res.append(action)
    return res

user_profiles = {
    'Bill': {
        'dietary_preferences': 'low_carb', 
        'avg_order_price': '0-20',
        'browser_type': 'edge'
    },
    'Satya': {
        'dietary_preferences': 'low_sodium',
        'avg_order_price': '201+',
        'browser_type': 'safari'
    },
    'Amy': {
        'dietary_preferences': {
            'vegan', 'vegetarian'
        },
        'avg_order_price': '21-50',
        'browser_type': 'edge'},
    }

def get_context(user):
    location_context = {'location': random.choice(['west', 'east', 'midwest'])}
    time_of_day = {'time_of_day': random.choice(['morning', 'afternoon', 'evening'])}
    app_type = {'application_type': random.choice(['edge', 'safari', 'edge_mobile', 'mobile_app'])}
    res = [user_profiles[user], location_context, time_of_day, app_type]
    return res

def get_random_users(k = 5):
    return random.choices(list(user_profiles.keys()), k=k)


def get_reward_score(user, actionid, context):
    reward_score = 0.0
    action = actions_and_features[actionid]
    
    if user == 'Bill':
        if action['attributes']['price'] < 10 and (context[1]['location'] !=  "midwest"):
            reward_score = 1.0
            print("Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought", actionid, "because it was below a price of $10.")
        elif (action['dietary_attributes']['low_carb'] == True) and (context[1]['location'] ==  "midwest"):
            reward_score = 1.0
            print("Bill is visiting his friend Warren in the midwest. There he's willing to spend more on food as long as it's low carb, so Bill bought" + actionid + ".")
            
        elif (action['attributes']['price'] >= 10) and (context[1]['location'] != "midwest"):
            print("Bill didn't buy", actionid, "because the price was too high when not visting his friend Warren in the midwest.")
            
        elif (action['dietary_attributes']['low_carb'] == False) and (context[1]['location'] ==  "midwest"):
            print("Bill didn't buy", actionid, "because it's not low-carb, and he's in the midwest visitng his friend Warren.")
             
    elif user == 'Satya':
        if action['dietary_attributes']['low_sodium'] == True:
            reward_score = 1.0
            print("Satya is health conscious, so he bought", actionid,"since it's low in sodium.")
        else:
            print("Satya did not buy", actionid, "because it's not low sodium.")   
            
    elif user == 'Amy':
        if (action['dietary_attributes']['vegan'] == True) or (action['dietary_attributes']['vegetarian'] == True):
            reward_score = 1.0
            print("Amy likes to eat plant-based foods, so she bought", actionid, "because it's vegan or vegetarian friendly.")       
        else:
            print("Amy did not buy", actionid, "because it's not vegan or vegetarian.")
                
    return reward_score

# %%
def run_personalizer_cycle():
    actions = get_actions()
    user_list = get_random_users()
    for user in user_list:
        print("------------")
        print("User:", user, "\n")
        context = get_context(user)
        print("Context:", context, "\n")
        
        rank_request = RankRequest(actions=actions, context_features=context)
        response = client.rank(rank_request=rank_request)
        print("Rank API response:", response, "\n")
        
        eventid = response.event_id
        actionid = response.reward_action_id
        print("Personalizer recommended action", actionid, "and it was shown as the featured product.\n")
        
        reward_score = get_reward_score(user, actionid, context)
        client.events.reward(event_id=eventid, value=reward_score)     
        print("\nA reward score of", reward_score , "was sent to Personalizer.")
        print("------------\n")

continue_loop = True
while continue_loop:
    run_personalizer_cycle()
    
    br = input("Press Q to exit, or any other key to run another loop: ")
    if(br.lower()=='q'):
        continue_loop = False
# </snippet_2>

# <snippet_multi>
for i in range(0,10):
    run_personalizer_cycle()
# </snippet_multi>
# Out:
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B855FEB8C0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560A9090>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560A8190>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560850F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856085350>], 'event_id': '6114505dca7447098048737f707184fa-fPYbw', 'reward_action_id': 'hummus'}
#
# Personalizer recommended action hummus and it was shown as the featured product.
#
# Satya did not buy hummus because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'afternoon'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85609C4D0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B855FEF240>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B855FEF350>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856055A50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856055550>], 'event_id': '3c009288df8d49889cee29ebeb9893d5-fPYbw', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85605B7A0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85605B890>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856100E50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561009F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560CB790>], 'event_id': 'b212f748b72142e4bbeb9100e4c82848-fPYbx', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Satya did not buy bbq because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85600B890>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85600B950>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856041860>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560422B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560951D0>], 'event_id': 'bb024c5617ee4caf9968baf66ad6f81a-fPYby', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
#
 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought veg_platter because it was below a price of $10.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'afternoon'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBA10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAF90>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB8F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBB30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBB90>], 'event_id': 'fd26fee8250f4ee5be9321e42b119996-fPYcc', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9DF0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9C10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9F70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9E50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBF50>], 'event_id': '4a40fb06408942c29f1374540036641a-fPYcd', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Bill is visiting his friend Warren in the midwest. There he's willing to spend more on food as long as it's low carb, so Bill boughtveg_platter.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105BB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561060F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107CB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561079B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107A10>], 'event_id': '0f792950f588432d90d47680b536363b-fPYcd', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107FB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBCB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB4D0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB830>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB530>], 'event_id': '2dc5cad56e2142d3a19ec63756528924-fPYce', 'reward_action_id': 'bao'}
#
# Personalizer recommended action bao and it was shown as the featured product.
#
# Bill is visiting his friend Warren in the midwest. There he's willing to spend more on food as long as it's low carb, so Bill boughtbao.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105BB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB050>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB590>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAB10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAC90>], 'event_id': 'bc1ae7166d224ded9f0c39330c94d730-fPYce', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107FB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA210>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA6F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA090>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9EB0>], 'event_id': '284144b9585548a9855d112ecc30ba26-fPYcf', 'reward_action_id': 'pasta'}
#
# Personalizer recommended action pasta and it was shown as the featured product.
#
# Amy did not buy pasta because it's not vegan or vegetarian.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'afternoon'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA090>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA6F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9EB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBA10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB8F0>], 'event_id': '89341d20d0074071a5f4615818d6cc77-fPYcf', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Bill is visiting his friend Warren in the midwest. There he's willing to spend more on food as long as it's low carb, so Bill boughtveg_platter.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561054F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105A90>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105A30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E8710>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9670>], 'event_id': 'a8216dab0238470385f3bcfb20a0c16c-fPYcg', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105B50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105910>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105970>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB8F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9850>], 'event_id': '6c9f783907344d8b869d57132ce8e95c-fPYcg', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105F70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561054F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561058B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606FCB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606FC50>], 'event_id': '313d738a79094f009201ddcd80b69b4d-fPYch', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9850>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105B50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105FD0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F770>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F830>], 'event_id': '0b17fd235a1940e4b1a956645d03afa3-fPYch', 'reward_action_id': 'bbq'}
#
# Personalizer recommended action bbq and it was shown as the featured product.
#
# Satya did not buy bbq because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'evening'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105490>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105BB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105430>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856106510>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560BDC10>], 'event_id': '9e19f4d009fd401a92d189e61486a6cb-fPYci', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# ...
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561068D0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856106A50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107710>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606EF90>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F290>], 'event_id': 'd9d81d821faf4849a1350991090f42cf-fPYcn', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9970>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107D10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105AF0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F4D0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F3B0>], 'event_id': '7a0e70d72cc54c05b0029d7679cf88a2-fPYcn', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought veg_platter because it was below a price of $10.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107BF0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561068D0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E95B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F6B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F8F0>], 'event_id': 'a9ff70890dc343f0a24794547c1c572c-fPYco', 'reward_action_id': 'bao'}
#
# Personalizer recommended action bao and it was shown as the featured product.
#
# Satya did not buy bao because it's not low sodium.
#
# A reward score of 0.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E8BF0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9970>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E93D0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F3B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F590>], 'event_id': 'eace4a1153cb4ecdb328bc047ad0de93-fPYcp', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F8F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F290>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606FD70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606FD10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606FB90>], 'event_id': 'd2078f8400064209842cb1227f565f51-fPYcp', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought veg_platter because it was below a price of $10.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Bill
#
# Context: [{'dietary_preferences': 'low_carb', 'avg_order_price': '0-20', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606EF30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F350>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F410>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856106FF0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107C50>], 'event_id': '241ed277903e47b5be7c801dc3540a64-fPYcq', 'reward_action_id': 'bao'}
#
# Personalizer recommended action bao and it was shown as the featured product.
#
# Bill likes to be economical when he's not in the midwest visiting his friend Warren. He bought bao because it was below a price of $10.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F8F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856105F70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856106E10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856106DB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856106810>], 'event_id': '8e36545350a94aa3a9f9a2c34638bb4d-fPYcq', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'evening'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606EF30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107290>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107230>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAA50>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAF30>], 'event_id': '762030ab4774443eaf2a9cc9872e8c26-fPYcq', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'afternoon'}, {'application_type': 'edge_mobile'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606F8F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAE70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAB70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA330>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA4B0>], 'event_id': '7ba598b26b78402aa9867e69580e14a5-fPYcr', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'east'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606EF30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAE70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAB70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA4B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E8BF0>], 'event_id': 'b841997a2b64441688303d43c4d6a6a9-fPYcr', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'west'}, {'time_of_day': 'afternoon'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBFB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB3B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EA2D0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB5F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E93D0>], 'event_id': '4e85c103444843fd951af752145b5629-fPYcs', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Amy
#
# Context: [{'dietary_preferences': {'vegan', 'vegetarian'}, 'avg_order_price': '21-50', 'browser_type': 'edge'}, {'location': 'midwest'}, {'time_of_day': 'morning'}, {'application_type': 'mobile_app'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606EF30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9C10>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9130>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB350>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBAD0>], 'event_id': 'e122e391b1a94e5abb6523439e8ffcba-fPYcs', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Amy likes to eat plant-based foods, so she bought veg_platter because it's vegan or vegetarian friendly.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'midwest'}, {'time_of_day': 'afternoon'}, {'application_type': 'safari'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561060F0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B856107CB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EBFB0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E9F70>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB230>], 'event_id': 'be4a2c738a5c45c1bab2a8850543811a-fPYct', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
#
# ------------
# User: Satya
#
# Context: [{'dietary_preferences': 'low_sodium', 'avg_order_price': '201+', 'browser_type': 'safari'}, {'location': 'west'}, {'time_of_day': 'morning'}, {'application_type': 'edge'}]
#
# Rank API response: {'additional_properties': {}, 'ranking': [<azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8561079B0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B85606EF30>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EB4D0>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560EAF90>, <azure.cognitiveservices.personalizer.models.ranked_action_py3.RankedAction object at 0x000002B8560E8650>], 'event_id': '968a51c60fd844299b0bffccff5268ef-fPYcu', 'reward_action_id': 'veg_platter'}
#
# Personalizer recommended action veg_platter and it was shown as the featured product.
#
# Satya is health conscious, so he bought veg_platter since it's low in sodium.
#
# A reward score of 1.0 was sent to Personalizer.
# ------------
