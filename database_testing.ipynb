# %%
import sys
import time
import dateutil
import dateutil.parser
from azure.cognitiveservices.personalizer import PersonalizerClient
from azure.cognitiveservices.personalizer.models import RankRequest
from msrest.authentication import CognitiveServicesCredentials
import pandas as pd
import numpy as np
import math
import time
from datetime import datetime, timedelta
from collections import Counter
import string
import pickle
import json
import pytz
import os
import re
import glob
import copy
import pyarrow as pa
from pyarrow import DirectoryPartitioning

# %%
outputtable = pa.dataset("C://Users//tpd10//Gits//bwh-pharmacoepi-roybal//000_TestDir//", format="csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 outputtable = pa.dataset("C://Users//tpd10//Gits//bwh-pharmacoepi-roybal//000_TestDir//", format="csv")
#
# AttributeError: module 'pyarrow' has no attribute 'dataset'
